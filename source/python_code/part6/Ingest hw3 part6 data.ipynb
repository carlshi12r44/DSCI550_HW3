# %%
import pandas as pd
import pysolr
import requests
from tqdm.notebook import tqdm
import os

# %%
df = pd.read_csv('part6_solr_input.csv')

# %%
df
# Out:
#         id                                             Emails
# 0        0  CONFIDENTIAL TEL: 233-27-587908.', 'E-MAIL: (j...
# 1        1  I am Mr. Ben Suleman a custom officer and work...
# 2        2  This letter might surprise you because we have...
# 3        3  This letter might surprise you because we have...
# 4        4  It is with a heart full of hope that I write t...
# 5        5  PRESIDENT/MANAGING DIRECTOR ', 'Request for Ur...
# 6        6  I am Barrister Tunde Dosumu (SAN) solicitor at...
# 7        7  president Tijani Kabba force in their struggle...
# 8        8  ATTENTION:MADAM/SIR', 'trustworthy and establi...
# 9        9  I am Barrister Tunde Dosumu (SAN) solicitor at...
# 10      10  DEMOCRATIC REPUBLIC OF CONGO.', 'TEL:44 777577...
# 11      11  THE MANAGER', 'Headquarter,', 'Alternative E-m...
# 12      12  SENIOR ADVOCATE OF NIGERIA', 'World Business E...
# 13      13  Good day.This very confidential request should...
# ...

# %%
json_docs = []
doc_id = 0
for index, row in tqdm(df.iterrows()):
    json_doc = {}
    json_doc["text"] = str(row['Emails'])
    json_doc["id"] = str(doc_id)
    doc_id  = doc_id +1
    json_docs.append(json_doc)

# %%
json_docs[:10]
# Out:
# [{'id': '0',
# ...

# %%
core_name = 'fraud_emails'
# Create a client instance. The timeout and authentication options are not required.
solr = pysolr.Solr('http://localhost:8983/solr/'+core_name, always_commit=True, timeout=10)

# %%
for doc in tqdm(json_docs):
    # How you'd index data.
    solr.add([
        doc
    ])
